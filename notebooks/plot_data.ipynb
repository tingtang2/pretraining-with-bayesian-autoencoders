# %%
import matplotlib.pyplot as plt
import json

# %%
ROOT = "/home/nrg2148/pretraining-with-bayesian-autoencoders/output/"
# EXPERIMENT_NAME = "regular_vae"
EXPERIMENT_NAME = "bayesian_decoder_vae"

# %%
elbo_file = open(ROOT + "metrics/{}_training_elbo_pretrain.json".format(EXPERIMENT_NAME))
elbo_data = json.load(elbo_file)
plt.plot(elbo_data)
plt.xlabel("training epochs")
plt.ylabel("ELBO")
# Out:
# Text(0, 0.5, 'ELBO')

# %%
reconstruct_file = open(ROOT + "metrics/{}_predictive_reconstruct_loss_pretrain.json".format(EXPERIMENT_NAME))
reconstruct_data = json.load(reconstruct_file)
plt.plot(reconstruct_data)
plt.xlabel("training epochs")
plt.ylabel("reconstruction loss")
# Out:
# Text(0, 0.5, 'reconstruction loss')
