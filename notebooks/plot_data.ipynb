# %%
import matplotlib.pyplot as plt
import json

# %%
ROOT = "/home/nrg2148/pretraining-with-bayesian-autoencoders/output/"
# EXPERIMENT_NAME = "regular_vae"
EXPERIMENT_NAME = "bayesian_encoder_vae"
E6 = "omniglot_conv_vae_bayesian_encoder_and_decoder"

# %%
elbo_file = open(ROOT + "metrics/{}_training_elbo_pretrain.json".format(E6))
elbo_data = json.load(elbo_file)
plt.plot(elbo_data[15:])
plt.xlabel("training epochs")
plt.ylabel("ELBO")
print(min(elbo_data))
print(max(elbo_data))
# Out:
# -1778151.0855975624
# -767.2529424199995

# %%
reconstruct_file = open(ROOT + "metrics/{}_predictive_reconstruct_loss_pretrain.json".format(E6))
reconstruct_data = json.load(reconstruct_file)
print(min(reconstruct_data))
plt.plot(reconstruct_data[10:])
plt.xlabel("training epochs")
plt.ylabel("reconstruction loss")
# Out:
# 689.4841284890776
# Text(0, 0.5, 'reconstruction loss')
